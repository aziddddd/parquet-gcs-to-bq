# %% [markdown]
# # Backfilling Script
# - Do not update/'git push' this notebook to git!

# %%
# Choose table to backfill.
# Uncomment all entry if want to backfill all tables.
table_info = [
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    },
    {
        'bucket-name': 'yourbucketname',
        'prefix': 'path/to/your/table/',
        'project-id': 'yourprojectid',
        'dataset-id': 'yourdatasetid',
        'table-id': 'yourtableid',
        'temp-table': 'true',
        'auto-schema': 'true',
        'write-disposition': 'WRITE_TRUNCATE',
        'partition-column': 'your_partition_column',
    }
]

# %%
import json

sa = 'your-sa-key.json'
project_id = 'yourprojectid'
dataset_id = 'yourdatasetid' 
location = 'US'
st = '2022-01-01'
ed = '2022-12-31'
dt_format = '%Y-%m-%d'
topic = 'yourtopic'

# %%
import os

SERVICE_ACC = f"/secret1/{sa}"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = SERVICE_ACC
os.environ["CLOUDSDK_PYTHON"] = "python3"

# %%
from datetime import datetime, timedelta
import pandas as pd

st_obj = datetime.strptime(st, dt_format)
ed_obj = datetime.strptime(ed, dt_format)

dates = [i.strftime(dt_format) for i in pd.date_range(st_obj, ed_obj, freq='d')]

# %% [markdown]
# ### Option 1 :  Loop per date
# - It will WRITE_APPEND to STG table
# - Uncomment if want to use

# %%
# for table in table_info:
#     bucket_name = table['bucket-name']
#     table_id = table['table-id']
#     prefix = table['prefix']
#     print(table_id)
#     for dt in dates:
#         !time python3 main.py \
#             --n-jobs 24 \
#             --bucket-name $bucket_name \
#             --prefix $prefix \
#             --st $dt \
#             --ed $dt \
#             --dt-format $dt_format \
#             --project-id $project_id \
#             --dataset-id  $dataset_id \
#             --table-id $table_id \
#             --location $location \
#             --temp-table true \
#             --auto-schema true \
#             --write-disposition WRITE_APPEND \
#             --sa $sa \
#             --topic $topic
#     print('--------------------------NEXT_TABLE--------------------------')

# %% [markdown]
# ### Option 2 : Loop per table
# - It will WRITE_TRUNCATE to STG table
# - Uncomment if want to use

# %%
# for table in table_info:
#     bucket_name = table['bucket-name']
#     table_id = table['table-id']
#     prefix = table['prefix']
#     print(table_id)
#     !time python3 main.py \
#         --n-jobs 24 \
#         --bucket-name $bucket_name \
#         --prefix $prefix \
#         --st $st \
#         --ed $ed \
#         --dt-format $dt_format \
#         --project-id $project_id \
#         --dataset-id  $dataset_id \
#         --table-id $table_id \
#         --location $location \
#         --temp-table true \
#         --auto-schema true \
#         --write-disposition WRITE_TRUNCATE \
#         --sa $sa \
#         --topic $topic
#     print('--------------------------NEXT_TABLE--------------------------')

# %% [markdown]
# ### Ingest stg table to prod table
# - Uncomment if want to use

# %%
# def ingest_stg_to_prod(
#     project_id:str,
#     dataset_id:str,
#     table_id:str,
#     partition_column:str,
# ):
#     return f"""
#         CREATE TABLE IF NOT EXISTS
#           `{project_id}.{dataset_id}.{table_id}` ({partition_column} DATETIME, table_is_empty STRING)
#         PARTITION BY
#           DATE({partition_column})
#         AS (
#           SELECT
#             CURRENT_DATE() {partition_column},
#             "" table_is_empty
#         );

#         CREATE TABLE IF NOT EXISTS `your-temp-dataset.TEMP.{table_id}_STG`
#         LIKE `{project_id}.{dataset_id}.{table_id}`;

#         INSERT INTO
#         `{project_id}.{dataset_id}.{table_id}`
#         SELECT
#           CAST({partition_column} AS DATETIME) {partition_column},
#           * EXCEPT ({partition_column})
#         FROM `your-temp-dataset.TEMP.{table_id}_STG`
#         WHERE CAST({partition_column} AS STRING) != "";

#         DROP TABLE `your-temp-dataset.TEMP.{table_id}_STG`;
#     """

# import google.cloud.bigquery as bq
# bq_client = bq.Client(project=project_id)

# for table in table_info:
#     query = ingest_stg_to_prod(
#         project_id=table['project-id'],
#         dataset_id=table['dataset-id'],
#         table_id=table['table-id'],
#         partition_column=table['partition-column'],
#     )
    
#     print(table)
#     print(query)

#     bq_job = bq_client.query(query)
#     bq_job.result() # Wait for BQ to finish execute

#     print('\n--------------------------NEXT_TABLE--------------------------\n')
